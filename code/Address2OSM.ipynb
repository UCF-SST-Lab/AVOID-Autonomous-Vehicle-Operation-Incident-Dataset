# %%
import osmnx as ox
import geopandas as gpd
place_name = "Noe valley, San Francisco"
area = ox.geocode_to_gdf(place_name)

# %%
area
# Out:
#                                             geometry  bbox_north  bbox_south  \
# 0  POLYGON ((-122.44500 37.74683, -122.44476 37.7...    37.75663   37.739661
#
#     bbox_east   bbox_west   place_id osm_type     osm_id        lat  \
# 0 -122.424025 -122.444998  242878370      way  689195738  37.751591
#
#           lon                                       display_name  class  \
# 0 -122.432081  Noe Valley, San Francisco, CAL Fire Northern R...  place
#
#             type  importance
# 0  neighbourhood    0.739307

# %%
area.plot()
# Out:
# <Axes: >

# %%
tags = {'building': True}   

buildings = ox.geometries_from_place(place_name, tags)
buildings.head()
# Out:
#                                                      name  \
# element_type osmid
# node         2094572330        Vista Del Monte Apartments
# way          32112931    St. Paul's Roman Catholic Church
#              32113140        Saint Paul's Catholic School
#              32113694                                 NaN
#              32117633            James Lick Middle School
#
#                                                                   geometry  \
# element_type osmid
# node         2094572330                        POINT (-122.43657 37.74339)
# way          32112931    POLYGON ((-122.42757 37.74433, -122.42755 37.7...
#              32113140    POLYGON ((-122.42737 37.74402, -122.42686 37.7...
#              32113694    POLYGON ((-122.42498 37.74062, -122.42485 37.7...
#              32117633    POLYGON ((-122.43295 37.74966, -122.43293 37.7...
#
#                         addr:state    building  ele       gnis:Class  \
# element_type osmid
# ...

# %%
buildings.plot()
# Out:
# <Axes: >

# %%
tags = {'leisure': True}   

buildings = ox.geometries_from_place(place_name, tags)
buildings.head()
# Out:
#                              created_by  ele gnis:county_id gnis:created  \
# element_type osmid
# node         358804951   Potlatch 0.10f   48            075   01/01/1995
#              360959372   Potlatch 0.10f  NaN            NaN          NaN
#              994238510              NaN  NaN            NaN          NaN
#              2637241462             NaN  NaN            NaN          NaN
#              2675601598             NaN  NaN            NaN          NaN
#
#                         gnis:feature_id gnis:state_id        leisure  \
# element_type osmid
# node         358804951          1656919            06           park
#              360959372              NaN           NaN         garden
#              994238510              NaN           NaN           park
#              2637241462             NaN           NaN  sports_centre
#              2675601598             NaN           NaN  sports_centre
#
#                                                 name   wikidata  \
# ...

# %%
buildings.plot()
# Out:
# <Axes: >
